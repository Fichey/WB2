# %%
# %pip --version
# Out:
# pip 25.0.1 from c:\Users\czare\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip (python 3.11)
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# test
